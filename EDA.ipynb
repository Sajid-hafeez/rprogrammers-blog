# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a dictionary representing the data
data = {'Name': ['John', 'Alita','Kaka','Crista', 'Charlie', 'Robert'],
        'Age': [38, 30, 35, 45, 15, 75],
        'Gender': ['Male', 'Female', 'Male', 'Female','Male','Male'],
       'Marks': [78, 45, 95, 15, 45, 68]}

# %%
# Create the data frame
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age  Gender  Marks
# 0     John   38    Male     78
# 1    Alita   30  Female     45
# 2     Kaka   35    Male     95
# 3   Crista   45  Female     15
# 4  Charlie   15    Male     45
# 5   Robert   75    Male     68

# %%
# Check the data types and count of missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Gender  6 non-null      object
#  3   Marks   6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
# Plot the heatmap of age and marks
plt.figure(figsize=(10, 6)) # Adjust the size of the figure
sns.heatmap(df[["Age", "Marks"]], annot=True, cmap="Blues") # Use the seaborn heatmap function
plt.title("Heatmap of Age and Marks") # Add a title to the plot
plt.show() # Show the plot

# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt

# Create a data frame from your data
df = pd.DataFrame({
    "Name": ["John", "Alita", "Kaka", "Crista", "Charlie", "Robert"],
    "Age": [38, 30, 35, 45, 15, 75],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Male"],
    "Marks": [78, 45, 95, 15, 45, 68]
})

# Plot the pie chart of names and marks
plt.figure(figsize=(10, 6)) # Adjust the size of the figure
plt.pie(df["Marks"], labels=df["Name"], autopct="%1.1f%%") # Use the matplotlib pie function
plt.title("Pie Chart of Names and Marks") # Add a title to the plot
plt.show() # Show the plot

# %%
# Summarize the numerical columns
df.describe()
# Out:
#              Age      Marks
# count   6.000000   6.000000
# mean   39.666667  57.666667
# std    20.016660  28.479232
# min    15.000000  15.000000
# 25%    31.250000  45.000000
# 50%    36.500000  56.500000
# 75%    43.250000  75.500000
# max    75.000000  95.000000

# %%
# Create a histogram of one of the numerical columns
plt.hist(df['Age'])
plt.show()

# %%
# Create a figure with a specific size
plt.figure(figsize=(10, 6))
# Create a histogram of one of the numerical columns
plt.hist(df['Age'],bins=4)

# Adjust the labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.suptitle('Histogram of Age', fontsize=20)            
plt.title('Rprogrammers.com',loc='left', fontsize=10)     #loc : {'center', 'left', 'right'}


# Show the plot
plt.show()

# %%
# Create a figure with a specific size
plt.figure(figsize=(10, 6))
sns.histplot(df,x='Age',bins=4)
# Adjust the labels and title
plt.xlabel('Age')
plt.ylabel('Density')
plt.suptitle('Histogram of Age', fontsize=20)            
plt.title('Rprogrammers.com',loc='left', fontsize=10)     #loc : {'center', 'left', 'right'}

# Show the plot
plt.show()

# %%
# Create a scatter plot of two of the numerical columns
plt.scatter(data=df,x='Age', y='Marks')
plt.show()

# %%
sns.lmplot(x='Age', y='Marks', data=df, fit_reg=True)

# %%
colors = {'Male':'tab:blue', 'Female':'tab:orange'}
# Create a scatter plot of two of the numerical columns
plt.scatter(df['Age'], df['Marks'],s=55,c=df['Gender'].map(colors),alpha=.5)
plt.show()

# %%
sns.lmplot(x='Age', y='Marks', data=df, hue='Gender', fit_reg=False)
plt.title("Age VS Marks")
# Out:
# Text(0.5, 1.0, 'Age VS Marks')

# %%
# Create a boxplot of the tip amount
sns.boxplot(data=df, x='Age')

# Show the plot
plt.show()

# %%
#Q1 - 1.5 * IQR 
#Q3 + 1.5 * IQR

# %%
# 2. Identify the numeric and non-numeric data columns.

num_columns = df.select_dtypes(exclude='object').columns
cat_columns = df.select_dtypes(include='object').columns

# %%
num_columns
# Out:
# Index(['Age', 'Marks'], dtype='object')

# %%
nCols=2   # The number of columns that you want
nRows=1   # The number of correspomding rows 

## to avoid rotating labels:
fig,axes = plt.subplots(nRows, nCols, figsize=(20,10))
for ind,col in enumerate(num_columns):
    sns.boxplot(x=col,data=df,ax=axes.flatten()[ind])
plt.suptitle('Boxplot of all numeric variables', fontsize=20)
plt.show()

# %%
# Use seaborn to create a pairplot of the data
sns.pairplot(df)
plt.show()

# %%
sns.countplot(data=df,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
# 2. Identify the numeric and non-numeric data columns.

num_columns = df.select_dtypes(exclude='object').columns
cat_columns = df.select_dtypes(include='object').columns

print(f'Numerical columns are: {num_columns.tolist()}')
print(f'Non-numerical columns are: {cat_columns.tolist()}')
# Out:
# Numerical columns are: ['Age', 'Marks']
# Non-numerical columns are: ['Name', 'Gender']

# %% [markdown]
# ## Pearson's *r* Correlation
#
# The following formula is used for calculating the Pearson's *r* correlation:
#
# $$
# r = \frac{N \sum xy-\sum x \sum y}{\sqrt{\left[N\sum x^2-\left(\sum x\right)^2\right]\left[N\sum y^2-\left(\sum y\right)^2\right]}}
# $$
#
# where
# $r$ = Pearson's *r* correlation coefficient, $-1\leq r \leq 1$
# $N$ = number of values in each dataset/column
# $\sum xy$ = sum of the products of the paired scores/columns
# $\sum x$= sum of x column scores
# $\sum y$= sum of y column scores
# $\sum x^2$= sum of squared x column scores
# $\sum y^2$= sum of squared y column scores

# %% [markdown]
# Pearson's r, also known as Pearson's correlation coefficient, is a measure of the linear relationship between two continuous variables. It is a statistical measure that ranges from -1 to 1, where -1 indicates a strong negative linear relationship, 0 indicates no linear relationship, and 1 indicates a strong positive linear relationship.

# %%
# 3. Use python and verify the above results.
corr = df.corr(method = 'pearson')
display(corr)
# Out:
# C:\Users\Sajid\AppData\Local\Temp\ipykernel_21384\1215085501.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method = 'pearson')
#             Age     Marks
# Age    1.000000  0.127823
# Marks  0.127823  1.000000

# %%
# 3.i. Histograms for each column 
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

nCols=2   # The number of columns that you want
nRows=1   # The number of correspomding rows 

## to avoid rotating labels:
fig,axes = plt.subplots(nRows, nCols, figsize=(20,10))
for ind,col in enumerate(cat_columns):
    sns.countplot(y=col,data=df,ax=axes.flatten()[ind])
plt.suptitle('Barplots of all categorical variables', fontsize=20)               #loc : {'center', 'left', 'right'}
plt.show()

# %%
## to avoid rotating labels:
fig,axes = plt.subplots(nRows, nCols, figsize=(20,10))
for ind,col in enumerate(num_columns):
    sns.histplot(y=col,data=df,ax=axes.flatten()[ind])
plt.suptitle('Histogram of all numeric variables', fontsize=20)               #loc : {'center', 'left', 'right'}
plt.show()

# %%
## to avoid rotating labels:
fig,axes = plt.subplots(nRows, nCols, figsize=(20,10))
for ind,col in enumerate(num_columns):
    sns.boxplot(x=col,data=df,ax=axes.flatten()[ind])
plt.suptitle('Boxplot of all numeric variables', fontsize=20)
plt.show()

# %%
## to avoid rotating labels:
fig,axes = plt.subplots(nRows, nCols, figsize=(20,10))
for ind,col in enumerate(num_columns):
    sns.violinplot(x=col,data=df,ax=axes.flatten()[ind])
plt.suptitle('Violin Plot of all numeric variables', fontsize=20)
plt.show()

# %%
# display(df.describe(include='all'))
display(df.describe(include='number'))
display(df.describe(include='object'))
# Out:
#              Age      Marks
# count   6.000000   6.000000
# mean   39.666667  57.666667
# std    20.016660  28.479232
# min    15.000000  15.000000
# 25%    31.250000  45.000000
# 50%    36.500000  56.500000
# 75%    43.250000  75.500000
# max    75.000000  95.000000
#         Name Gender
# count      6      6
# unique     6      2
# top     John   Male
# freq       1      4

# %%
#     4.ii. Histograms for each column differentiated by *subscribed* column.
for col in num_columns:
    plt.figure(figsize=(5,5))
    sns.histplot(x=col,bins=5,hue='Gender',data=df,palette=['r','b'])
    plt.xticks(rotation=45)
    plt.show()

# %%
#     4.iii. Draw a bivariate histogram for *age* and *balance* columns.
plt.figure(figsize=(5,5))
sns.histplot(x='Age', y='Marks', bins=5, data=df)
plt.show()

# %%
plt.figure()
sns.pairplot(vars=num_columns,hue ='Gender',data=df)  
plt.show()

# %%
ctab = pd.crosstab(df['Gender'],df['Name'])
display(ctab)
# Out:
# Name    Alita  Charlie  Crista  John  Kaka  Robert
# Gender
# Female      1        0       1     0     0       0
# Male        0        1       0     1     1       1

# %%
df = pd.DataFrame({'Animal': ['Dog','Elephant', 'Cat', 'Dog', 'Dog', 'Cat', 'Cat'],
                   'Color': ['Black','Grey', 'Black', 'Gray', 'White', 'Gray', 'White'],
                   'Size': ['Small', 'Large', 'Medium', 'Large', 'Large', 'Small', 'Medium']})

df
# Create a cross-tabulation of the Animal and Color variables
ct = pd.crosstab(df['Color'], df['Size'])
ct
# Out:
# Size   Large  Medium  Small
# Color
# Black      0       1      1
# Gray       1       0      1
# Grey       1       0      0
# White      1       1      0
